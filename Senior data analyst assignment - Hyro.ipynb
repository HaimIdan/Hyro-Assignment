# %%
import pandas as pd
import ast
import json
import os
from datetime import datetime

# Read the CSV file
df = pd.read_csv(r"C:\Users\User\Projects\Hyro\Senior data analyst assignment - Hyro.csv")

# %%
# saving up our conversation dimensions to the side
conversation_dim = df.drop(columns=['LIST_OF_EVENTS_TYPES_IN_ORDER','LIST_OF_EVENTS_DATA_IN_ORDER'])

# %%
# Convert the string representation of the list to an actual Python list
df['LIST_OF_EVENTS_TYPES_IN_ORDER'] = df['LIST_OF_EVENTS_TYPES_IN_ORDER'].apply(ast.literal_eval)

# %%
# Create a new DataFrame with both the event type and its position
List_of_events = df.apply(lambda row: 
    pd.DataFrame({
        'CONVERSATION_ID': row['CONVERSATION_ID'],
        'ASSISTANT_ID': row['ASSISTANT_ID'],
        'EVENT_TYPE': row['LIST_OF_EVENTS_TYPES_IN_ORDER'],
        'EVENT_POSITION': range(1, len(row['LIST_OF_EVENTS_TYPES_IN_ORDER']) + 1)
    })
, axis=1)

# Concatenate the individual DataFrames
List_of_events = pd.concat(List_of_events.tolist(), ignore_index=True)

# Display the first few rows to verify and check the number of rows
print(List_of_events.head())
print("\nNumber of rows:", len(List_of_events))
# Out:
#                         CONVERSATION_ID                          ASSISTANT_ID  \
# 0  6bbd6279-e3e8-4292-ad47-bc245df28c29  08fd0ad8-b8bd-4c6d-a1bf-c381dbe24b4d
# 1  6bbd6279-e3e8-4292-ad47-bc245df28c29  08fd0ad8-b8bd-4c6d-a1bf-c381dbe24b4d
# 2  6bbd6279-e3e8-4292-ad47-bc245df28c29  08fd0ad8-b8bd-4c6d-a1bf-c381dbe24b4d
# 3  6bbd6279-e3e8-4292-ad47-bc245df28c29  08fd0ad8-b8bd-4c6d-a1bf-c381dbe24b4d
# 4  6bbd6279-e3e8-4292-ad47-bc245df28c29  08fd0ad8-b8bd-4c6d-a1bf-c381dbe24b4d
#
#                  EVENT_TYPE  EVENT_POSITION
# 0  CONVERSATION_TTL_SECONDS               1
# 1          CONNECTION_EVENT               2
# 2               WIDGET_LOAD               3
# 3  CONVERSATION_TTL_SECONDS               4
# 4          CONNECTION_EVENT               5
#
# Number of rows: 161419

# %%
# Try to parse the JSON without everything breaking
def safe_parse_json(json_str):
    try:
        # First, attempt to parse as JSON
        return json.loads(json_str)
    except json.JSONDecodeError:
        try:
            # If JSON parsing fails, try to clean and parse
            # Remove any Python-like list syntax
            cleaned_str = json_str.replace('\n', '').replace(' ', '')
            return json.loads(cleaned_str)
        except:
            # If all else fails, return the original string
            return json_str

# Apply the safe parsing function
df['LIST_OF_EVENTS_DATA_IN_ORDER'] = df['LIST_OF_EVENTS_DATA_IN_ORDER'].apply(safe_parse_json)

# Create a new DataFrame with event data info
List_of_events_data = df.apply(lambda row: 
    pd.DataFrame({
        'CONVERSATION_ID': row['CONVERSATION_ID'],
        'ASSISTANT_ID': row['ASSISTANT_ID'],
        'EVENT_POSITION': range(1, len(row['LIST_OF_EVENTS_DATA_IN_ORDER']) + 1),
        'EVENT_DATA': row['LIST_OF_EVENTS_DATA_IN_ORDER']
    })
, axis=1)

# Concatenate the individual DataFrames
List_of_events_data = pd.concat(List_of_events_data.tolist(), ignore_index=True)

# Display the first few rows to verify
print(List_of_events_data.head())

# Check the number of rows
print("\nNumber of rows:", len(List_of_events_data))
# Out:
#                         CONVERSATION_ID                          ASSISTANT_ID  \
# 0  6bbd6279-e3e8-4292-ad47-bc245df28c29  08fd0ad8-b8bd-4c6d-a1bf-c381dbe24b4d
# 1  6bbd6279-e3e8-4292-ad47-bc245df28c29  08fd0ad8-b8bd-4c6d-a1bf-c381dbe24b4d
# 2  6bbd6279-e3e8-4292-ad47-bc245df28c29  08fd0ad8-b8bd-4c6d-a1bf-c381dbe24b4d
# 3  6bbd6279-e3e8-4292-ad47-bc245df28c29  08fd0ad8-b8bd-4c6d-a1bf-c381dbe24b4d
# 4  6bbd6279-e3e8-4292-ad47-bc245df28c29  08fd0ad8-b8bd-4c6d-a1bf-c381dbe24b4d
#
#    EVENT_POSITION                                         EVENT_DATA
# 0               1  {'eventData': {'ttl': 900}, 'eventId': '670ea9...
# 1               2  {'eventData': {'isTest': False, 'location': {'...
# 2               3  {'eventData': {'isTest': False, 'location': {'...
# 3               4  {'eventData': {'ttl': 900}, 'eventId': '670ea9...
# 4               5  {'eventData': {'isTest': False, 'location': {'...
#
# Number of rows: 161419

# %%
# Merge the two DataFrames
List_of_events_data = List_of_events_data.merge(
    List_of_events, 
    on=['CONVERSATION_ID', 'ASSISTANT_ID', 'EVENT_POSITION'], 
    how='left'
)

# Check the columns after merging
print("\nColumns after merge:", list(List_of_events_data.columns))
# Out:
# Columns after merge: ['CONVERSATION_ID', 'ASSISTANT_ID', 'EVENT_POSITION', 'EVENT_DATA', 'EVENT_TYPE']

# %%
# Let's get all unique event types
unique_event_types = List_of_events_data['EVENT_TYPE'].unique()

# Create a dictionary to store DataFrames for each event type
event_type_dfs = {}

# Iterate through unique event types
for event_type in unique_event_types:
    # Filter the DataFrame for the current event type
    df_filtered = List_of_events_data[List_of_events_data['EVENT_TYPE'] == event_type].copy()
    
    # Parse the EVENT_DATA for this specific type
    df_parsed = df_filtered.apply(lambda row: 
        pd.Series({
            'CONVERSATION_ID': row['CONVERSATION_ID'],
            'ASSISTANT_ID': row['ASSISTANT_ID'],
            'EVENT_POSITION': row['EVENT_POSITION'],
            **row['EVENT_DATA'],  # Unpack the main dictionary
            **row['EVENT_DATA'].get('eventData', {})  # Unpack nested eventData
        }), axis=1)
    
    # Store the parsed DataFrame in the dictionary
    event_type_dfs[event_type] = df_parsed

# Print out the event types and their DataFrame sizes
for event_type, df in event_type_dfs.items():
    print(f"Event Type: {event_type}")
    print(f"Number of rows: {len(df)}")
    print("Columns:", list(df.columns))
    print("\n")
# Out:
# Event Type: CONVERSATION_TTL_SECONDS
# Number of rows: 16393
# Columns: ['CONVERSATION_ID', 'ASSISTANT_ID', 'EVENT_POSITION', 'eventData', 'eventId', 'timestamp', 'typeOfEvent', 'ttl']
#
#
# Event Type: CONNECTION_EVENT
# Number of rows: 14118
# Columns: ['CONVERSATION_ID', 'ASSISTANT_ID', 'EVENT_POSITION', 'eventData', 'eventId', 'timestamp', 'typeOfEvent', 'isTest', 'location']
#
#
# Event Type: WIDGET_LOAD
# Number of rows: 14118
# Columns: ['CONVERSATION_ID', 'ASSISTANT_ID', 'EVENT_POSITION', 'eventData', 'eventId', 'timestamp', 'typeOfEvent', 'isTest', 'location', 'referrer']
#
#
# Event Type: WIDGET_CLICK
# Number of rows: 9717
# Columns: ['CONVERSATION_ID', 'ASSISTANT_ID', 'EVENT_POSITION', 'eventData', 'eventId', 'timestamp', 'typeOfEvent', 'name']
#
#
# Event Type: SWITCH_COMMAND
# Number of rows: 4880
# Columns: ['ASSISTANT_ID', 'CONVERSATION_ID', 'EVENT_POSITION', 'commandType', 'data', 'eventData', 'eventId', 'sender', 'timestamp', 'typeOfEvent']
#
#
# Event Type: THINKING
# Number of rows: 51687
# Columns: ['CONVERSATION_ID', 'ASSISTANT_ID', 'EVENT_POSITION', 'eventData', 'eventId', 'timestamp', 'typeOfEvent', 'block', 'on']
#
#
# Event Type: BOT_UTTERANCE
# Number of rows: 10144
# Columns: ['@text', 'ASSISTANT_ID', 'CONVERSATION_ID', 'EVENT_POSITION', 'blacklist', 'browserCommands', 'disambiguation', 'eventData', 'eventId', 'events', 'explicitContextDrop', 'hints', 'httpRequest', 'lowSttConfidence', 'matchedTextPairs', 'nluEngineVersion', 'renderingFlags', 'requestLatency', 'results', 'sender', 'suggestions', 'switchCommands', 'tags', 'text', 'timestamp', 'typeOfEvent']
#
#
# Event Type: SUGGESTION_CLICK
# Number of rows: 2275
# Columns: ['@date', '@fax', '@phone', 'ASSISTANT_ID', 'CONVERSATION_ID', 'EVENT_POSITION', 'date', 'displayText', 'eventData', 'eventId', 'eventsToSend', 'fax', 'httpRequest', 'imageUrl', 'isBoxed', 'isSticky', 'metadata', 'phone', 'readAloud', 'sayText', 'showInSms', 'source', 'timestamp', 'typeOfEvent', 'url']
#
#
# Event Type: USER_UTTERANCE
# Number of rows: 6044
# Columns: ['@utterance', 'ASSISTANT_ID', 'CONVERSATION_ID', 'EVENT_POSITION', 'arrivedWhileProcessingPreviousUtterance', 'arrivedWhileSpeaking', 'cloudRecordingId', 'data', 'eventData', 'eventId', 'provider', 'speechDuration', 'sttConfidence', 'timestamp', 'typeOfEvent', 'utterance', 'utteranceType']
#
#
# Event Type: MAPPED_TERM
# Number of rows: 6359
# Columns: ['CONVERSATION_ID', 'ASSISTANT_ID', 'EVENT_POSITION', 'eventData', 'eventId', 'timestamp', 'typeOfEvent', 'nluEngineVersion', 'requestLatency', 'semantics', 'tokenPath', 'type']
#
#
# Event Type: KNOWLEDGE
# Number of rows: 4861
# Columns: ['CONVERSATION_ID', 'ASSISTANT_ID', 'EVENT_POSITION', 'eventData', 'eventId', 'timestamp', 'typeOfEvent', 'graphId', 'nluEngineVersion', 'requestLatency', 'titleOrNodeId', 'types']
#
#
# Event Type: FOLLOWUP_QUESTION
# Number of rows: 2280
# Columns: ['CONVERSATION_ID', 'ASSISTANT_ID', 'EVENT_POSITION', 'eventData', 'eventId', 'timestamp', 'typeOfEvent', 'blacklist', 'browserCommands', 'disambiguation', 'events', 'explicitContextDrop', 'httpRequest', 'lowSttConfidence', 'nluEngineVersion', 'renderingFlags', 'requestLatency', 'results', 'suggestions', 'switchCommands', 'tags', 'text']
#
#
# Event Type: SAID
# Number of rows: 2973
# Columns: ['CONVERSATION_ID', 'ASSISTANT_ID', 'EVENT_POSITION', 'eventData', 'eventId', 'timestamp', 'typeOfEvent', 'nluEngineVersion', 'requestLatency', 'said']
#
#
# Event Type: PROVIDER_MEDICAL_ATTRIBUTE
# Number of rows: 2271
# Columns: ['ASSISTANT_ID', 'CONVERSATION_ID', 'EVENT_POSITION', 'bodyPart', 'condition', 'eventData', 'eventId', 'expertise', 'familyMember', 'gender', 'informationPage', 'interest', 'location', 'name', 'nluEngineVersion', 'professionalSuffix', 'requestLatency', 'salientTerm', 'specialty', 'subspecialty', 'symptom', 'timestamp', 'type', 'typeOfEvent']
#
#
# Event Type: SEARCH_PERFORMED
# Number of rows: 2327
# Columns: ['CONVERSATION_ID', 'ASSISTANT_ID', 'EVENT_POSITION', 'eventData', 'eventId', 'timestamp', 'typeOfEvent', 'constraints', 'nluEngineVersion', 'requestLatency', 'resultCount', 'type']
#
#
# Event Type: BOT_SOCKET_CLOSED
# Number of rows: 2471
# Columns: ['CONVERSATION_ID', 'ASSISTANT_ID', 'EVENT_POSITION', 'eventData', 'eventId', 'timestamp', 'typeOfEvent', 'code', 'reason']
#
#
# Event Type: CONVERSATION_TTL_REACHED
# Number of rows: 2275
# Columns: ['CONVERSATION_ID', 'ASSISTANT_ID', 'EVENT_POSITION', 'eventData', 'eventId', 'timestamp', 'typeOfEvent', 'lastUtteranceSource']
#
#
# Event Type: INTENT
# Number of rows: 104
# Columns: ['ASSISTANT_ID', 'CONVERSATION_ID', 'EVENT_POSITION', 'eventData', 'eventId', 'key', 'name', 'nluEngineVersion', 'requestLatency', 'timestamp', 'typeOfEvent']
#
#
# Event Type: CANNED_RESPONSE
# Number of rows: 869
# Columns: ['CONVERSATION_ID', 'ASSISTANT_ID', 'EVENT_POSITION', 'eventData', 'eventId', 'timestamp', 'typeOfEvent', 'nluEngineVersion', 'requestLatency', 'triggers']
#
#
# Event Type: MISUNDERSTANDING
# Number of rows: 410
# Columns: ['ASSISTANT_ID', 'CONVERSATION_ID', 'EVENT_POSITION', 'eventData', 'eventId', 'nluEngineVersion', 'reason', 'requestLatency', 'timestamp', 'typeOfEvent']
#
#
# Event Type: URL_TAG_CLICK
# Number of rows: 541
# Columns: ['CONVERSATION_ID', 'ASSISTANT_ID', 'EVENT_POSITION', 'eventData', 'eventId', 'timestamp', 'typeOfEvent', 'url']
#
#
# Event Type: CHAT_CONVERSATION_ENDED
# Number of rows: 310
# Columns: ['CONVERSATION_ID', 'ASSISTANT_ID', 'EVENT_POSITION', 'eventData', 'eventId', 'timestamp', 'typeOfEvent', 'lastUtteranceSource', 'reason']
#
#
# Event Type: RESULT_CLICK
# Number of rows: 690
# Columns: ['CONVERSATION_ID', 'ASSISTANT_ID', 'EVENT_POSITION', 'eventData', 'eventId', 'timestamp', 'typeOfEvent', '@address', 'address', 'avatarUrl', 'contentType', 'data', 'edges', 'headers', 'imageUrl', 'latlng', 'price', 'suggestions', 'tags', 'text', 'title', 'url']
#
#
# Event Type: CTA_CLICK
# Number of rows: 171
# Columns: ['CONVERSATION_ID', 'ASSISTANT_ID', 'EVENT_POSITION', 'eventData', 'eventId', 'timestamp', 'typeOfEvent', 'action', 'displayText']
#
#
# Event Type: MAP_CLICK
# Number of rows: 90
# Columns: ['CONVERSATION_ID', 'ASSISTANT_ID', 'EVENT_POSITION', 'eventData', 'eventId', 'timestamp', 'typeOfEvent']
#
#
# Event Type: FEEDBACK
# Number of rows: 527
# Columns: ['CONVERSATION_ID', 'ASSISTANT_ID', 'EVENT_POSITION', 'eventData', 'eventId', 'timestamp', 'typeOfEvent', 'feedbackId', 'nluEngineVersion', 'requestLatency', 'resultsType']
#
#
# Event Type: START_RECORDING
# Number of rows: 154
# Columns: ['CONVERSATION_ID', 'ASSISTANT_ID', 'EVENT_POSITION', 'eventData', 'eventId', 'timestamp', 'typeOfEvent']
#
#
# Event Type: AUDIO_STREAM
# Number of rows: 125
# Columns: ['ASSISTANT_ID', 'CONVERSATION_ID', 'EVENT_POSITION', 'eventData', 'eventId', 'sampleRate', 'sampleSize', 'streamType', 'timestamp', 'typeOfEvent']
#
#
# Event Type: AUDIO_MANAGER
# Number of rows: 59
# Columns: ['CONVERSATION_ID', 'ASSISTANT_ID', 'EVENT_POSITION', 'eventData', 'eventId', 'timestamp', 'typeOfEvent', 'newAudioManager']
#
#
# Event Type: STT_PROVIDER
# Number of rows: 58
# Columns: ['CONVERSATION_ID', 'ASSISTANT_ID', 'EVENT_POSITION', 'eventData', 'eventId', 'timestamp', 'typeOfEvent', 'provider']
#
#
# Event Type: LEXICON_MATCH
# Number of rows: 191
# Columns: ['CONVERSATION_ID', 'ASSISTANT_ID', 'EVENT_POSITION', 'eventData', 'eventId', 'timestamp', 'typeOfEvent', 'nluEngineVersion', 'phrase', 'predictions', 'requestLatency']
#
#
# Event Type: LIST_VIEW_CLICK
# Number of rows: 151
# Columns: ['CONVERSATION_ID', 'ASSISTANT_ID', 'EVENT_POSITION', 'eventData', 'eventId', 'timestamp', 'typeOfEvent']
#
#
# Event Type: INFEASIBLE
# Number of rows: 367
# Columns: ['CONVERSATION_ID', 'ASSISTANT_ID', 'EVENT_POSITION', 'eventData', 'eventId', 'timestamp', 'typeOfEvent', 'nluEngineVersion', 'requestLatency']
#
#
# Event Type: INTEGRATION_SERVER_REQUEST
# Number of rows: 90
# Columns: ['CONVERSATION_ID', 'ASSISTANT_ID', 'EVENT_POSITION', 'eventData', 'eventId', 'timestamp', 'typeOfEvent', 'botKey', 'data', 'integrationId', 'method', 'nluEngineVersion', 'requestLatency']
#
#
# Event Type: FLOW_STARTED
# Number of rows: 90
# Columns: ['CONVERSATION_ID', 'ASSISTANT_ID', 'EVENT_POSITION', 'eventData', 'eventId', 'timestamp', 'typeOfEvent', 'nluEngineVersion', 'requestLatency', 'skillInstance', 'type']
#
#
# Event Type: INTEGRATION_REQUEST_RESULT
# Number of rows: 90
# Columns: ['CONVERSATION_ID', 'ASSISTANT_ID', 'EVENT_POSITION', 'eventData', 'eventId', 'timestamp', 'typeOfEvent', 'nluEngineVersion', 'request', 'requestLatency', 'response']
#
#
# Event Type: LIVE_CHAT_AGENTS_AVAILABILITY
# Number of rows: 96
# Columns: ['CONVERSATION_ID', 'ASSISTANT_ID', 'EVENT_POSITION', 'eventData', 'eventId', 'timestamp', 'typeOfEvent', 'data', 'nluEngineVersion', 'requestLatency']
#
#
# Event Type: SPEECH_LANGUAGE
# Number of rows: 401
# Columns: ['CONVERSATION_ID', 'ASSISTANT_ID', 'EVENT_POSITION', 'eventData', 'eventId', 'timestamp', 'typeOfEvent', 'lang', 'nluEngineVersion', 'requestLatency']
#
#
# Event Type: STT_SPEECH_CONTEXT
# Number of rows: 90
# Columns: ['CONVERSATION_ID', 'ASSISTANT_ID', 'EVENT_POSITION', 'eventData', 'eventId', 'timestamp', 'typeOfEvent', 'nluEngineVersion', 'requestLatency', 'speechContexts']
#
#
# Event Type: FACT_COLLECTED
# Number of rows: 226
# Columns: ['@dateOfBirth', '@personName', 'ASSISTANT_ID', 'CONVERSATION_ID', 'EVENT_POSITION', 'confirmedHandoff', 'dateOfBirth', 'eventData', 'eventId', 'nluEngineVersion', 'personName', 'requestLatency', 'timestamp', 'typeOfEvent']
#
#
# Event Type: DISAMBIGUATION_HINT
# Number of rows: 77
# Columns: ['CONVERSATION_ID', 'ASSISTANT_ID', 'EVENT_POSITION', 'eventData', 'eventId', 'timestamp', 'typeOfEvent', 'nluEngineVersion', 'requestLatency', 'type']
#
#
# Event Type: FREE_TEXT
# Number of rows: 75
# Columns: ['CONVERSATION_ID', 'ASSISTANT_ID', 'EVENT_POSITION', 'eventData', 'eventId', 'timestamp', 'typeOfEvent', 'key', 'nluEngineVersion', 'requestLatency', 'value']
#
#
# Event Type: HANDOFF
# Number of rows: 72
# Columns: ['CONVERSATION_ID', 'ASSISTANT_ID', 'EVENT_POSITION', 'eventData', 'eventId', 'timestamp', 'typeOfEvent', 'nluEngineVersion', 'requestLatency', 'to']
#
#
# Event Type: AGENT_CONNECTED
# Number of rows: 72
# Columns: ['CONVERSATION_ID', 'ASSISTANT_ID', 'EVENT_POSITION', 'eventData', 'eventId', 'timestamp', 'typeOfEvent', 'agentId', 'successfulConnection']
#
#
# Event Type: DEVICE_INFO
# Number of rows: 1
# Columns: ['CONVERSATION_ID', 'ASSISTANT_ID', 'EVENT_POSITION', 'eventData', 'eventId', 'timestamp', 'typeOfEvent', 'innerHeight', 'innerWidth', 'isMobile', 'model', 'os', 'osVersion', 'ua', 'vendor']
#
#
# Event Type: INSURANCE_PROVIDER
# Number of rows: 29
# Columns: ['CONVERSATION_ID', 'ASSISTANT_ID', 'EVENT_POSITION', 'eventData', 'eventId', 'timestamp', 'typeOfEvent', 'insuranceProvider', 'nluEngineVersion', 'requestLatency']

# %%
# Function to convert unix timestamp (milliseconds) to datetime
def convert_unix_to_datetime(unix_ms):
    try:
        return datetime.fromtimestamp(unix_ms / 1000.0)
    except:
        return None

# Iterate through each DataFrame in event_type_dfs
for event_type, df in event_type_dfs.items():
    # Check if 'timestamp' column exists in this DataFrame
    if 'timestamp' in df.columns:
        # Convert the timestamp
        df['timestamp'] = df['timestamp'].apply(convert_unix_to_datetime)
        print(f"Converted timestamps for: {event_type}")

# Verify the conversion for each DataFrame
for event_type, df in event_type_dfs.items():
    if 'timestamp' in df.columns:
        print(f"\nEvent Type: {event_type}")
        print("Timestamp sample:")
        print(df['timestamp'].head())
# Out:
# Converted timestamps for: CONVERSATION_TTL_SECONDS
# Converted timestamps for: CONNECTION_EVENT
# Converted timestamps for: WIDGET_LOAD
# Converted timestamps for: WIDGET_CLICK
# Converted timestamps for: SWITCH_COMMAND
# Converted timestamps for: THINKING
# Converted timestamps for: BOT_UTTERANCE
# Converted timestamps for: SUGGESTION_CLICK
# Converted timestamps for: USER_UTTERANCE
# Converted timestamps for: MAPPED_TERM
# Converted timestamps for: KNOWLEDGE
# Converted timestamps for: FOLLOWUP_QUESTION
# Converted timestamps for: SAID
# Converted timestamps for: PROVIDER_MEDICAL_ATTRIBUTE
# Converted timestamps for: SEARCH_PERFORMED
# Converted timestamps for: BOT_SOCKET_CLOSED
# Converted timestamps for: CONVERSATION_TTL_REACHED
# Converted timestamps for: INTENT
# Converted timestamps for: CANNED_RESPONSE
# Converted timestamps for: MISUNDERSTANDING
# Converted timestamps for: URL_TAG_CLICK
# Converted timestamps for: CHAT_CONVERSATION_ENDED
# Converted timestamps for: RESULT_CLICK
# Converted timestamps for: CTA_CLICK
# Converted timestamps for: MAP_CLICK
# Converted timestamps for: FEEDBACK
# Converted timestamps for: START_RECORDING
# Converted timestamps for: AUDIO_STREAM
# Converted timestamps for: AUDIO_MANAGER
# Converted timestamps for: STT_PROVIDER
# Converted timestamps for: LEXICON_MATCH
# Converted timestamps for: LIST_VIEW_CLICK
# Converted timestamps for: INFEASIBLE
# Converted timestamps for: INTEGRATION_SERVER_REQUEST
# Converted timestamps for: FLOW_STARTED
# Converted timestamps for: INTEGRATION_REQUEST_RESULT
# Converted timestamps for: LIVE_CHAT_AGENTS_AVAILABILITY
# Converted timestamps for: SPEECH_LANGUAGE
# Converted timestamps for: STT_SPEECH_CONTEXT
# Converted timestamps for: FACT_COLLECTED
# Converted timestamps for: DISAMBIGUATION_HINT
# Converted timestamps for: FREE_TEXT
# Converted timestamps for: HANDOFF
# Converted timestamps for: AGENT_CONNECTED
# Converted timestamps for: DEVICE_INFO
# Converted timestamps for: INSURANCE_PROVIDER
#
# Event Type: CONVERSATION_TTL_SECONDS
# Timestamp sample:
# 0    2024-10-15 20:43:21.285
# 3    2024-10-15 20:43:59.678
# 6    2024-10-15 20:44:08.311
# 9    2024-10-15 20:45:13.783
# 12   2024-10-15 20:45:16.303
# Name: timestamp, dtype: datetime64[ns]
#
# Event Type: CONNECTION_EVENT
# Timestamp sample:
# 1    2024-10-15 20:43:21.286
# 4    2024-10-15 20:43:59.679
# 7    2024-10-15 20:44:08.312
# 10   2024-10-15 20:45:13.784
# 13   2024-10-15 20:45:16.304
# Name: timestamp, dtype: datetime64[ns]
#
# Event Type: WIDGET_LOAD
# Timestamp sample:
# 2    2024-10-15 20:43:21.287
# 5    2024-10-15 20:43:59.680
# 8    2024-10-15 20:44:08.313
# 11   2024-10-15 20:45:13.785
# 14   2024-10-15 20:45:16.305
# Name: timestamp, dtype: datetime64[ns]
#
# Event Type: WIDGET_CLICK
# Timestamp sample:
# 15   2024-10-15 20:45:38.886
# 48   2024-10-15 20:46:30.366
# 56   2024-10-15 20:46:42.813
# 64   2024-10-15 20:47:07.522
# 87   2024-10-15 15:35:34.820
# Name: timestamp, dtype: datetime64[ns]
#
# Event Type: SWITCH_COMMAND
# Timestamp sample:
# 16    2024-10-15 20:45:38.891
# 18    2024-10-15 20:45:38.893
# 88    2024-10-15 15:35:34.823
# 90    2024-10-15 15:35:34.825
# 172   2024-10-15 22:29:42.463
# Name: timestamp, dtype: datetime64[ns]
#
# Event Type: THINKING
# Timestamp sample:
# 19   2024-10-15 20:45:38.918
# 20   2024-10-15 20:45:39.236
# 24   2024-10-15 20:45:56.804
# 25   2024-10-15 20:45:57.349
# 33   2024-10-15 20:46:01.306
# Name: timestamp, dtype: datetime64[ns]
#
# Event Type: BOT_UTTERANCE
# Timestamp sample:
# 21   2024-10-15 20:45:39.237
# 30   2024-10-15 20:45:57.354
# 41   2024-10-15 20:46:02.276
# 42   2024-10-15 20:46:02.277
# 93   2024-10-15 15:35:35.268
# Name: timestamp, dtype: datetime64[ns]
#
# Event Type
# Name: timestamp, dtype: datetime64[ns]
#
# Event Type: DEVICE_INFO
# Timestamp sample:
# 16601   2024-10-02 21:01:21.657
# Name: timestamp, dtype: datetime64[ns]
#
# Event Type: INSURANCE_PROVIDER
# Timestamp sample:
# 17261   2024-10-03 00:42:50.566
# 25725   2024-10-13 15:02:53.461
# 29398   2024-10-10 18:44:02.948
# 32682   2024-10-10 22:48:15.191
# 34777   2024-10-06 16:05:55.795
# Name: timestamp, dtype: datetime64[ns]

# %%
# Creating a directory for all of our exported data
export_dir = os.path.join(os.getcwd(), 'data_tables')
os.makedirs(export_dir, exist_ok=True)

# Export each event type DataFrame
for event_type, df in event_type_dfs.items():
    # Create a filename by replacing any spaces or special characters with underscores
    filename = f"{event_type.replace(' ', '_').replace('/', '_')}_events.csv"
    filepath = os.path.join(export_dir, filename)
    
    # Export to CSV
    df.to_csv(filepath, index=False)
    print(f"Exported: {filename}")

# Export our main List_of_events_data
list_events_data_filepath = os.path.join(export_dir, 'List_of_events_data.csv')
List_of_events_data.to_csv(list_events_data_filepath, index=False)
print(f"\nExported: List_of_events_data.csv")

# Export our conversation dimension 
conversation_dim_filepath = os.path.join(export_dir, 'Conversation_dimension.csv')
conversation_dim.to_csv(conversation_dim_filepath, index=False)
print(f"\nExported: Conversation_dimension.csv")

# Print the directory where files are saved
print(f"\nAll files exported to: {export_dir}")
# Out:
# Exported: CONVERSATION_TTL_SECONDS_events.csv
# Exported: CONNECTION_EVENT_events.csv
# Exported: WIDGET_LOAD_events.csv
# Exported: WIDGET_CLICK_events.csv
# Exported: SWITCH_COMMAND_events.csv
# Exported: THINKING_events.csv
# Exported: BOT_UTTERANCE_events.csv
# Exported: SUGGESTION_CLICK_events.csv
# Exported: USER_UTTERANCE_events.csv
# Exported: MAPPED_TERM_events.csv
# Exported: KNOWLEDGE_events.csv
# Exported: FOLLOWUP_QUESTION_events.csv
# Exported: SAID_events.csv
# Exported: PROVIDER_MEDICAL_ATTRIBUTE_events.csv
# Exported: SEARCH_PERFORMED_events.csv
# Exported: BOT_SOCKET_CLOSED_events.csv
# Exported: CONVERSATION_TTL_REACHED_events.csv
# Exported: INTENT_events.csv
# Exported: CANNED_RESPONSE_events.csv
# Exported: MISUNDERSTANDING_events.csv
# Exported: URL_TAG_CLICK_events.csv
# Exported: CHAT_CONVERSATION_ENDED_events.csv
# Exported: RESULT_CLICK_events.csv
# Exported: CTA_CLICK_events.csv
# Exported: MAP_CLICK_events.csv
# Exported: FEEDBACK_events.csv
# Exported: START_RECORDING_events.csv
# Exported: AUDIO_STREAM_events.csv
# Exported: AUDIO_MANAGER_events.csv
# Exported: STT_PROVIDER_events.csv
# Exported: LEXICON_MATCH_events.csv
# Exported: LIST_VIEW_CLICK_events.csv
# Exported: INFEASIBLE_events.csv
# Exported: INTEGRATION_SERVER_REQUEST_events.csv
# Exported: FLOW_STARTED_events.csv
# Exported: INTEGRATION_REQUEST_RESULT_events.csv
# Exported: LIVE_CHAT_AGENTS_AVAILABILITY_events.csv
# Exported: SPEECH_LANGUAGE_events.csv
# Exported: STT_SPEECH_CONTEXT_events.csv
# Exported: FACT_COLLECTED_events.csv
# Exported: DISAMBIGUATION_HINT_events.csv
# Exported: FREE_TEXT_events.csv
# Exported: HANDOFF_events.csv
# Exported: AGENT_CONNECTED_events.csv
# Exported: DEVICE_INFO_events.csv
# Exported: INSURANCE_PROVIDER_events.csv
#
# Exported: List_of_events_data.csv
#
# Exported: Conversation_dimension.csv
#
# All files exported to: C:\Users\User\Projects\Hyro\data_tables
